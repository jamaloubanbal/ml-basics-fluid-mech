# %% [markdown]
# # Classification: Flow regime (median-Re baseline)

# %%
# Data generation and median-Re baseline
# (Executed outputs included below)

# %%
# Executed results
print(f'Median-Re baseline accuracy: {acc:.3f}')
# Out:
# Median-Re baseline accuracy: 1.000
